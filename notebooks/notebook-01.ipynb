# %%
import sys
import os

# Add the path to the 'scripts' directory
scripts_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts'))
if scripts_path not in sys.path:
    sys.path.append(scripts_path)

from analysis import analyze_conversations

analysis = analyze_conversations(4, 0.3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       7     sys.path.append(scripts_path)
#       9 from analysis import analyze_conversations
# ---> 11 analysis = analyze_conversations(4, 0.3)
#
# File ~/Sync/Git/GitHub/alastair87/chatgpt-analysis/scripts/analysis.py:15, in analyze_conversations(n_weeks, energy_per_query_wh)
#      12 tokenizer = tiktoken.encoding_for_model("gpt-4o")
#      14 # Load conversations from exported JSON file
# ---> 15 with open('conversations.json', 'r', encoding='utf-8') as f:
#      16     data = json.load(f)
#      18 # Track messages and tokens
#
# FileNotFoundError: [Errno 2] No such file or directory: 'conversations.json'
